# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
# Import API key
from config import open_weather_api_key

# %%
# Set starting url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + open_weather_api_key

# %%
# Create sets of random latitudes and logitudes
lats = np.random.uniform(low =-90.00, high=90.00, size=2000)
lngs = np.random.uniform(low =-180.00, high=180.00, size=2000)
# Pack into zip object
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add latitude/longitude combos to list
coordinates = list(lat_lngs)

# %%
# Create list to hold cities
cities = []
# Identify nearest cities to coordinates
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # Only add to list if city is unique
    if city not in cities:
        cities.append(city)

# %%
# Print city count
len(cities)
# Out:
# 745

# %%
cities
# Out:
# ['albany',
#  'cabo san lucas',
#  'haines junction',
#  'esperance',
#  'vaini',
#  'honiara',
#  'vostok',
#  'punta arenas',
#  'victoria',
#  'nchelenge',
#  'barrow',
#  'planaltina',
#  'raga',
#  'bestobe',
#  'belmonte',
#  'jamestown',
#  'goderich',
#  'ushuaia',
#  'tessalit',
#  'kapaa',
#  'taolanaro',
#  'illoqqortoormiut',
#  'lebu',
#  'lokosovo',
#  'belushya guba',
#  'pochutla',
#  'mataura',
#  'rikitea',
#  'katsuura',
#  'new norfolk',
#  'okulovka',
#  'cidreira',
#  'winnemucca',
#  'vardo',
#  'qaanaaq',
#  'tumannyy',
#  'alamos',
#  'zaragoza',
#  'arroyo',
#  'lotofaga',
#  'puerto quijarro',
#  'buala',
#  'lompoc',
#  'port elizabeth',
#  'mount gambier',
#  'nikolskoye',
#  'pisco',
#  'tsihombe',
#  'calabozo',
#  'biak',
#  'preobrazheniye',
#  'ostrovnoy',
#  'hithadhoo',
#  'oistins',
#  'bredasdorp',
#  'santa ines',
#  'kodiak',
#  'cape town',
#  'necochea',
#  'beira',
#  'arraial do cabo',
#  'poum',
#  'caravelas',
#  'alofi',
#  'codrington',
#  'amderma',
#  'chapais',
#  'juegang',
#  'sitka',
#  'lagos',
#  'busselton',
#  'ponta do sol',
#  'umzimvubu',
#  'moyobamba',
#  'ballina',
#  'rawson',
#  'ambon',
#  'tatarsk',
#  'yellowknife',
#  'ugoofaaru',
#  'china',
#  'iqaluit',
#  'xingcheng',
#  'tambo grande',
#  'ancud',
#  'sao jose da coroa grande',
#  'talnakh',
#  'namatanai',
#  'dikson',
#  'alyangula',
#  'atuona',
#  'areia branca',
#  'abu samrah',
#  'tanshui',
#  'mys shmidta',
#  'guerrero negro',
#  'onokhoy',
#  'bratsk',
#  'hobart',
#  'bathsheba',
#  'muscat',
#  'abha',
#  'avarua',
#  'petropavlovskoye',
#  'buraydah',
#  'saint-louis',
#  'luba',
#  'bluff',
#  'lorengau',
#  'pangnirtung',
#  'ilulissat',
#  'chernyshevskiy',
#  'clyde river',
#  'kijang',
#  'honningsvag',
#  'chau doc',
#  'starosubkhangulovo',
#  'fortuna',
#  'hilo',
#  'tuktoyaktuk',
#  'maniitsoq',
#  'galgani',
#  'luderitz',
#  'khatanga',
#  'udachnyy',
#  'qiyang',
#  'half moon bay',
#  'zhuanghe',
#  'hofn',
#  'puerto ayora',
#  'laguna',
#  'vertientes',
#  'wasilla',
#  'nanortalik',
#  'talaya',
#  'naze',
#  'chuy',
#  'nizhneyansk',
#  'berlevag',
#  'puerto escondido',
#  'itigi',
#  'gazli',
#  'qujing',
#  'kutum',
#  'vilyuysk',
#  'sherpur',
#  'fort nelson',
#  'mar del plata',
#  'isangel',
#  'mirandopolis',
#  'kjollefjord',
#  'verkhoyansk',
#  'elizabeth city',
#  'kieta',
#  'umarkot',
#  'darhan',
#  'hermanus',
#  'paamiut',
#  'uwayl',
#  'palmer',
#  'ilinskiy',
#  'odesskoye',
#  'letterkenny',
#  'kaitangata',
#  'maloy',
#  'malayal',
#  'aflu',
#  'provideniya',
#  'kruisfontein',
#  'cherskiy',
#  'mozarlandia',
#  'keti bandar',
#  'castro',
#  'norman wells',
#  'constitucion',
#  'arlit',
#  'jalu',
#  'east london',
#  'assiniboia',
#  'georgetown',
#  'husavik',
#  'batticaloa',
#  'saint-philippe',
#  'hasaki',
#  'milkovo',
#  'chokurdakh',
#  'quelimane',
#  'wamba',
#  'nizwa',
#  'tasiilaq',
#  'borovoy',
#  'mahebourg',
#  'kuching',
#  'bakel',
#  'saint marys',
#  'torbay',
#  'patratu',
#  'bethel',
#  'kattivakkam',
#  'narsaq',
#  'bengkulu',
#  'nata',
#  'sofiysk',
#  'bongaree',
#  'te anau',
#  'pierre',
#  'alushta',
#  'rumonge',
#  'oum hadjer',
#  'little current',
#  'salalah',
#  'nueva helvecia',
#  'pudozh',
#  'santa cruz del sur',
#  'hay river',
#  'saint-felicien',
#  'ahipara',
#  'camacha',
#  'ulagan',
#  'butaritari',
#  'saint-francois',
#  'bambous virieux',
#  'leningradskiy',
#  'laguna de perlas',
#  'adrar',
#  'ituni',
#  'carnarvon',
#  'upernavik',
#  'airai',
#  'viedma',
#  'robertsport',
#  'lerwick',
#  'tromso',
#  'touba',
#  'pevek',
#  'palm valley',
#  'ipeti',
#  'olafsvik',
#  'masjed-e soleyman',
#  'cajibio',
#  'cockburn town',
#  'attawapiskat',
#  'sirfa',
#  'saleaula',
#  'neiafu',
#  'tubuala',
#  'pullman',
#  'broken hill',
#  'tabiauea',
#  'zarand',
#  'tiksi',
#  'requena',
#  'malwan',
#  'thompson',
#  'vila velha',
#  'grindavik',
#  'luganville',
#  'tiznit',
#  'catio',
#  'gigmoto',
#  'faya',
#  'butterworth',
#  'la ronge',
#  'karatau',
#  'molokovo',
#  'syasstroy',
#  'majene',
#  'alta floresta',
#  'shache',
#  'hokitika',
#  'yulara',
#  'lanas',
#  'goma',
#  'san vicente',
#  'curup',
#  'coquimbo',
#  'am timan',
#  'kakori',
#  'silva jardim',
#  'praia da vitoria',
#  'marcona',
#  'alenquer',
#  'asau',
#  'rio gallegos',
#  'tautira',
#  'tuatapere',
#  'arman',
#  'port blair',
#  'flinders',
#  'agirish',
#  'lalganj',
#  'bat khela',
#  'changli',
#  'olinda',
#  'port alfred',
#  'agadir',
#  'richards bay',
#  'muisne',
#  'mogadishu',
#  'nalut',
#  'velsk',
#  'grand gaube',
#  'nsoko',
#  'rehoboth',
#  'dauphin',
#  'xingyi',
#  'elliot lake',
#  'nome',
#  'miraflores',
#  'hovd',
#  'kavieng',
#  'berezovka',
#  'peace river',
#  'riyadh',
#  'alegrete',
#  'doha',
#  'maku',
#  'tidore',
#  'avera',
#  'arani',
#  'tocopilla',
#  'tura',
#  'port hardy',
#  'el roble',
#  'moree',
#  'iwanai',
#  'fare',
#  'kuytun',
#  'baykit',
#  'hukuntsi',
#  'pangkalanbuun',
#  'show low',
#  'brae',
#  'miguel hidalgo',
#  'barentsburg',
#  'wulanhaote',
#  'wokha',
#  'teahupoo',
#  'ambilobe',
#  'yatou',
#  'vredendal',
#  'miramar',
#  'melfi',
#  'opuwo',
#  'ha tinh',
#  'ankazobe',
#  'andenes',
#  'bakal',
#  'mingyue',
#  'saravan',
#  'yangambi',
#  'saskylakh',
#  'dalbandin',
#  'turtas',
#  'kalinovskaya',
#  'lagoa',
#  'longyan',
#  'umm kaddadah',
#  'goundam',
#  'abu dhabi',
#  'quchan',
#  'palabuhanratu',
#  'petropavlovka',
#  'severnyy',
#  'hualmay',
#  'reshetylivka',
#  'sosnovka',
#  'kabwe',
#  'filingue',
#  'samalaeulu',
#  'mayo',
#  'mersing',
#  'maldonado',
#  'chabahar',
#  'korla',
#  'havelock',
#  'andevoranto',
#  'sao joao da barra',
#  'det udom',
#  'dwarka',
#  'ribeira grande',
#  'benghazi',
#  'anta',
#  'bac lieu',
#  'sento se',
#  'vestmannaeyjar',
#  'sedelnikovo',
#  'kismayo',
#  'pangody',
#  'samarai',
#  'vila do maio',
#  'hamilton',
#  'margate',
#  'comodoro rivadavia',
#  'preeceville',
#  'grebenskaya',
#  'los llanos de aridane',
#  'la rioja',
#  'algiers',
#  'llallagua',
#  'toora-khem',
#  'roma',
#  'keningau',
#  'balikpapan',
#  'kampot',
#  'jinchengjiang',
#  'san patricio',
#  'wajima',
#  'vaitupu',
#  'mount isa',
#  'buin',
#  'lata',
#  'tambacounda',
#  'peniche',
#  'ifakara',
#  'pietarsaari',
#  'yar-sale',
#  'sisimiut',
#  'belaya gora',
#  'lundazi',
#  'le port',
#  'hambantota',
#  'khonuu',
#  'geraldton',
#  'yanan',
#  'mokhsogollokh',
#  'gunjur',
#  'guamuchil',
#  'marsa matruh',
#  'bonavista',
#  'great yarmouth',
#  'vanino',
#  'bojnurd',
#  'saint george',
#  'lolua',
#  'severo-kurilsk',
#  'lujiang',
#  'navalmoral de la mata',
#  'aripuana',
#  'yumen',
#  'saldanha',
#  'lida',
#  'mocuba',
#  'touros',
#  'talavera',
#  'zarichne',
#  'imbituba',
#  'batemans bay',
#  'toliary',
#  'gasa',
#  'elektrogorsk',
#  'sinnamary',
#  'grand river south east',
#  'kaifeng',
#  'lamu',
#  'ponta delgada',
#  'scalloway',
#  'semey',
#  'suntar',
#  'flagstaff',
#  'parry sound',
#  'dunedin',
#  'tiarei',
#  'rolim de moura',
#  'yerbogachen',
#  'bridgton',
#  'temerloh',
#  'port macquarie',
#  'flin flon',
#  'nador',
#  'japura',
#  'russell',
#  'deshna',
#  'totma',
#  'wageningen',
#  'qasigiannguit',
#  'diego de almagro',
#  'qiongshan',
#  'dombarovskiy',
#  'waipawa',
#  'ossora',
#  'kirensk',
#  'north battleford',
#  'manado',
#  'coihaique',
#  'stornoway',
#  'buritis',
#  'tilichiki',
#  'kyzyl-suu',
#  'port-cartier',
#  'hun',
#  'sentyabrskiy',
#  'amapa',
#  'lasa',
#  'firozpur jhirka',
#  'kuche',
#  'nichinan',
#  'senneterre',
#  'petropavlovsk-kamchatskiy',
#  'piterka',
#  'sorland',
#  'makung',
#  'phuket',
#  'faanui',
#  'ust-kamchatsk',
#  'santa fe',
#  'mrirt',
#  'emerald',
#  'miyazu',
#  'khandyga',
#  'sinjar',
#  'veraval',
#  'bat yam',
#  'panguipulli',
#  'san carlos de bariloche',
#  'magistralnyy',
#  'makhachkala',
#  'bilibino',
#  'saint-joseph',
#  'jacqueville',
#  'saint-georges',
#  'alberton',
#  'tazovskiy',
#  'storsteinnes',
#  'bronnoysund',
#  'tanout',
#  'bubaque',
#  'komsomolskiy',
#  'carballo',
#  'rungata',
#  'gushi',
#  'yongan',
#  'rio brilhante',
#  'vanimo',
#  'grants',
#  'walvis bay',
#  'kayes',
#  'tolaga bay',
#  'eureka',
#  'klaksvik',
#  'morondava',
#  'yelandur',
#  'kodinsk',
#  'kalmunai',
#  'cabedelo',
#  'auki',
#  'pio ix',
#  'suez',
#  'zhezkazgan',
#  'college',
#  'warqla',
#  'naliya',
#  'norrtalje',
#  'kallithea',
#  'sturgis',
#  'sotouboua',
#  'bambanglipuro',
#  'anloga',
#  'kamogawa',
#  'illora',
#  'acapulco',
#  'ngukurr',
#  'warrensburg',
#  'mullaitivu',
#  'nouadhibou',
#  'danilovka',
#  'the pas',
#  'guangyuan',
#  'nehe',
#  'khasan',
#  'kharp',
#  'pak chong',
#  'manaure',
#  'sinkat',
#  'berdyuzhye',
#  'kyshtovka',
#  'grand-santi',
#  'itaituba',
#  'meulaboh',
#  'shingu',
#  'bacuit',
#  'americus',
#  'ginir',
#  'cayenne',
#  'apodi',
#  'dawson creek',
#  'benemerito de las americas',
#  'sao sebastiao',
#  'fukue',
#  'broome',
#  'labuhan',
#  'namibe',
#  'verkh-usugli',
#  'floresta',
#  'novo cruzeiro',
#  'cotonou',
#  'harper',
#  'aksay',
#  'madimba',
#  'olden',
#  'dzhebariki-khaya',
#  'maraa',
#  'saint-augustin',
#  'utete',
#  'tinskoy',
#  'rocha',
#  'kargasok',
#  'pedra',
#  'san cristobal',
#  'poronaysk',
#  'lulea',
#  'lensk',
#  'phan thiet',
#  'suba',
#  'campos novos',
#  'arona',
#  'abeche',
#  'aklavik',
#  'hvammstangi',
#  'svetlyy',
#  'varkkallai',
#  'sucua',
#  'hinton',
#  'nishihara',
#  'beringovskiy',
#  'san pedro',
#  'ahome',
#  'mirabad',
#  'itarema',
#  'guatire',
#  'tuzha',
#  'sao filipe',
#  'rantepao',
#  'saint anthony',
#  'mehran',
#  'radcliff',
#  'taoudenni',
#  'sampit',
#  'inuvik',
#  'bath',
#  'shizunai',
#  'deputatskiy',
#  'saint-gilles',
#  'numan',
#  'rafaela',
#  'krasnyy yar',
#  'quatre cocos',
#  'jega',
#  'yomitan',
#  'kibungo',
#  'bjerkvik',
#  'mergui',
#  'satitoa',
#  'panguna',
#  'padang',
#  'anadyr',
#  'balakhta',
#  'asyut',
#  'murray bridge',
#  'stromness',
#  'elko',
#  'mazamet',
#  'toktogul',
#  'coolum beach',
#  'sassandra',
#  'chilca',
#  'gurgan',
#  'dingle',
#  'nemuro',
#  'pyapon',
#  'oranjemund',
#  'valenca',
#  'port hedland',
#  'bihac',
#  'puerto madryn',
#  'lusaka',
#  'aykhal',
#  'almaznyy',
#  'valparaiso',
#  'oltu',
#  'verkhnevilyuysk',
#  'borgarnes',
#  'plouzane',
#  'puerto lopez',
#  'cozumel',
#  'kisangani',
#  'praya',
#  'mombasa',
#  'shieli',
#  'sarh',
#  'semnan',
#  'redcliffe',
#  'san ramon',
#  'cabatuan',
#  'kigoma',
#  'linjiang',
#  'betsiamites',
#  'leshukonskoye',
#  'praia',
#  'samarinda',
#  'bainbridge',
#  'kudahuvadhoo',
#  'iracoubo',
#  'tecoanapa',
#  'zharkent',
#  'rohtak',
#  'vao',
#  'kediri',
#  'nuuk',
#  'cheyenne',
#  'jutai',
#  'novobirilyussy',
#  'viligili',
#  'kasempa',
#  'palana',
#  'angoche',
#  'bouake',
#  'shubarshi',
#  'najran',
#  'dryden',
#  'managua',
#  'zabaykalsk',
#  'shirokiy',
#  'jiroft',
#  'joshimath',
#  'pidhorodne',
#  'leh',
#  'plettenberg bay',
#  'hihifo',
#  'ulaanbaatar',
#  'bur gabo',
#  'azimur',
#  'mwinilunga',
#  'saint-leu',
#  'beloha',
#  'cascais',
#  'mackay',
#  'carutapera',
#  'bereda',
#  'halifax',
#  'raudeberg',
#  'pontianak',
#  'longyearbyen',
#  'ginda',
#  'umea']

# %%
test_city = requests.get(url + "&q=" + "dondo").json()

# %%
test_city["weather"][0]["description"]
# Out:
# 'clear sky'

# %%
# Create empty list to hold city data
city_data = []
# Print beginning of logging
print("Beginning Data Retrieval    ")
print("------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through cities in list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    # Create url for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, record, and set numbers and city
    print(f'Processing record {record_count} of set {set_count} | {city}')
    record_count +=1

    # Run API request for each city
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Add city info to list
        city_data.append({"City":city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Current Description": city_current})
    # Skip city if error occurs
    except:
        print("City not found. Skipping...")
        pass
print("---------------------------")
print("done")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 1 | albany
# Processing record 2 of set 1 | cabo san lucas
# Processing record 3 of set 1 | haines junction
# Processing record 4 of set 1 | esperance
# Processing record 5 of set 1 | vaini
# Processing record 6 of set 1 | honiara
# Processing record 7 of set 1 | vostok
# Processing record 8 of set 1 | punta arenas
# Processing record 9 of set 1 | victoria
# Processing record 10 of set 1 | nchelenge
# Processing record 11 of set 1 | barrow
# Processing record 12 of set 1 | planaltina
# Processing record 13 of set 1 | raga
# Processing record 14 of set 1 | bestobe
# Processing record 15 of set 1 | belmonte
# Processing record 16 of set 1 | jamestown
# Processing record 17 of set 1 | goderich
# Processing record 18 of set 1 | ushuaia
# Processing record 19 of set 1 | tessalit
# Processing record 20 of set 1 | kapaa
# Processing record 21 of set 1 | taolanaro
# City not found. Skipping...
# Processing record 22 of set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing record 23 of set 1 | lebu
# Processing record 24 of set 1 | lokosovo
# Processing record 25 of set 1 | belushya guba
# City not found. Skipping...
# Processing record 26 of set 1 | pochutla
# Processing record 27 of set 1 | mataura
# Processing record 28 of set 1 | rikitea
# Processing record 29 of set 1 | katsuura
# Processing record 30 of set 1 | new norfolk
# Processing record 31 of set 1 | okulovka
# Processing record 32 of set 1 | cidreira
# Processing record 33 of set 1 | winnemucca
# Processing record 34 of set 1 | vardo
# Processing record 35 of set 1 | qaanaaq
# Processing record 36 of set 1 | tumannyy
# City not found. Skipping...
# Processing record 37 of set 1 | alamos
# Processing record 38 of set 1 | zaragoza
# Processing record 39 of set 1 | arroyo
# Processing record 40 of set 1 | lotofaga
# Processing record 41 of set 1 | puerto quijarro
# Processing record 42 of set 1 | buala
# Processing record 43 of set 1 | lompoc
# Processing record 44 of set 1 | port elizabeth
# Processing record 45 of set 1 | mount gambier
# Processing record 46 of set 1 | nikolskoye
# Processing record 47 of set 1 | pisco
# Processing record 48 of set 1 | tsihombe
# City not found. Skipping...
# Processing record 49 of set 1 | calabozo
# Processing record 50 of set 1 | biak
# Processing record 1 of set 2 | preobrazheniye
# Processing record 2 of set 2 | ostrovnoy
# Processing record 3 of set 2 | hithadhoo
# Processing record 4 of set 2 | oistins
# Processing record 5 of set 2 | bredasdorp
# Processing record 6 of set 2 | santa ines
# Processing record 7 of set 2 | kodiak
# Processing record 8 of set 2 | cape town
# Processing record 9 of set 2 | necochea
# Processing record 10 of set 2 | beira
# Processing record 11 of set 2 | arraial do cabo
# Processing record 12 of set 2 | poum
# Processing record 13 of set 2 | caravelas
# Processing record 14 of set 2 | alofi
# Processing record 15 of set 2 | codrington
# Processing record 16 of set 2 | amderma
# City not found. Skipping...
# Processing record 17 of set 2 | chapais
# Processing record 18 of set 2 | juegang
# Processing record 19 of set 2 | sitka
# Processing record 20 of set 2 | lagos
# Processing record 21 of set 2 | busselton
# Processing record 22 of set 2 | ponta do sol
# Processing record 23 of set 2 | umzimvubu
# City not found. Skipping...
# Processing record 24 of set 2 | moyobamba
# Processing record 25 of set 2 | ballina
# Processing record 26 of set 2 | rawson
# Processing record 27 of set 2 | ambon
# Processing record 28 of set 2 | tatarsk
# Processing record 29 of set 2 | yellowknife
# Processing record 30 of set 2 | ugoofaaru
# Processing record 31 of set 2 | china
# Processing record 32 of set 2 | iqaluit
# Processing record 33 of set 2 | xingcheng
# Processing record 34 of set 2 | tambo grande
# Processing record 35 of set 2 | ancud
# Processing record 36 of set 2 | sao jose da coroa grande
# Processing record 37 of set 2 | talnakh
# Processing record 38 of set 2 | namatanai
# Processing record 39 of set 2 | dikson
# Processing record 40 of set 2 | alyangula
# Processing record 41 of set 2 | atuona
# Processing record 42 of set 2 | areia branca
# Processing record 43 of set 2 | abu samrah
# Processing record 44 of set 2 | tanshui
# City not found. Skipping...
# Processing record 45 of set 2 | mys shmidta
# City not found. Skipping...
# Processing record 46 of set 2 | guerrero negro
# Processing record 47 of set 2 | onokhoy
# Processing record 48 of set 2 | bratsk
# Processing record 49 of set 2 | hobart
# Processing record 50 of set 2 | bathsheba
# Processing record 1 of set 3 | muscat
# Processing record 2 of set 3 | abha
# Processing record 3 of set 3 | avarua
# Processing record 4 of set 3 | petropavlovskoye
# Processing record 5 of set 3 | buraydah
# Processing record 6 of set 3 | saint-louis
# Processing record 7 of set 3 | luba
# Processing record 8 of set 3 | bluff
# Processing record 9 of set 3 | lorengau
# Processing record 10 of set 3 | pangnirtung
# Processing record 11 of set 3 | ilulissat
# Processing record 12 of set 3 | chernyshevskiy
# Processing record 13 of set 3 | clyde river
# Processing record 14 of set 3 | kijang
# Processing record 15 of set 3 | honningsvag
# Processing record 16 of set 3 | chau doc
# Processing record 17 of set 3 | starosubkhangulovo
# Processing record 18 of set 3 | fortuna
# Processing record 19 of set 3 | hilo
# Processing record 20 of set 3 | tuktoyaktuk
# Processing record 21 of set 3 | maniitsoq
# Processing record 22 of set 3 | galgani
# City not found. Skipping...
# Processing record 23 of set 3 | luderitz
# Processing record 24 of set 3 | khatanga
# Processing record 25 of set 3 | udachnyy
# Processing record 26 of set 3 | qiyang
# Processing record 27 of set 3 | half moon bay
# Processing record 28 of set 3 | zhuanghe
# Processing record 29 of set 3 | hofn
# Processing record 30 of set 3 | puerto ayora
# Processing record 31 of set 3 | laguna
# Processing record 32 of set 3 | vertientes
# Processing record 33 of set 3 | wasilla
# Processing record 34 of set 3 | nanortalik
# Processing record 35 of set 3 | talaya
# Processing record 36 of set 3 | naze
# Processing record 37 of set 3 | chuy
# Processing record 38 of set 3 | nizhneyansk
# City not found. Skipping...
# Processing record 39 of set 3 | berlevag
# Processing record 40 of set 3 | puerto escondido
# Processing record 41 of set 3 | itigi
# Processing record 42 of set 3 | gazli
# Processing record 43 of set 3 | qujing
# Processing record 44 of set 3 | kutum
# Processing record 45 of set 3 | vilyuysk
# Processing record 46 of set 3 | sherpur
# Processing record 47 of set 3 | fort nelson
# Processing record 48 of set 3 | mar del plata
# Processing record 49 of set 3 | isangel
# Processing record 50 of set 3 | mirandopolis
# Processing record 1 of set 4 | kjollefjord
# Processing record 2 of set 4 | verkhoyansk
# Processing record 3 of set 4 | elizabeth city
# Processing record 4 of set 4 | kieta
# Processing record 5 of set 4 | umarkot
# Processing record 6 of set 4 | darhan
# Processing record 7 of set 4 | hermanus
# Processing record 8 of set 4 | paamiut
# Processing record 9 of set 4 | uwayl
# City not found. Skipping...
# Processing record 10 of set 4 | palmer
# Processing record 11 of set 4 | ilinskiy
# Processing record 12 of set 4 | odesskoye
# Processing record 13 of set 4 | letterkenny
# Processing record 14 of set 4 | kaitangata
# Processing record 15 of set 4 | maloy
# Processing record 16 of set 4 | malayal
# Processing record 17 of set 4 | aflu
# City not found. Skipping...
# Processing record 18 of set 4 | provideniya
# Processing record 19 of set 4 | kruisfontein
# Processing record 20 of set 4 | cherskiy
# Processing record 21 of set 4 | mozarlandia
# Processing record 22 of set 4 | keti bandar
# Processing record 23 of set 4 | castro
# Processing record 24 of set 4 | norman wells
# Processing record 25 of set 4 | constitucion
# Processing record 26 of set 4 | arlit
# Processing record 27 of set 4 | jalu
# Processing record 28 of set 4 | east london
# Processing record 29 of set 4 | assiniboia
# Processing record 30 of set 4 | georgetown
# Processing record 31 of set 4 | husavik
# Processing record 32 of set 4 | batticaloa
# Processing record 33 of set 4 | saint-philippe
# Processing record 34 of set 4 | hasaki
# Processing record 35 of set 4 | milkovo
# Processing record 36 of set 4 | chokurdakh
# Processing record 37 of set 4 | quelimane
# Processing record 38 of set 4 | wamba
# Processing record 39 of set 4 | nizwa
# Processing record 40 of set 4 | tasiilaq
# Processing record 41 of set 4 | borovoy
# Processing record 42 of set 4 | mahebourg
# Processing record 43 of set 4 | kuching
# Processing record 44 of set 4 | bakel
# Processing record 45 of set 4 | saint marys
# Processing record 46 of set 4 | torbay
# Processing record 47 of set 4 | patratu
# City not found. Skipping...
# Processing record 48 of set 4 | bethel
# Processing record 49 of set 4 | kattivakkam
# Processing record 50 of set 4 | narsaq
# Processing record 1 of set 5 | bengkulu
# Processing record 2 of set 5 | nata
# Processing record 3 of set 5 | sofiysk
# City not found. Skipping...
# Processing record 4 of set 5 | bongaree
# Processing record 5 of set 5 | te anau
# Processing record 6 of set 5 | pierre
# Processing record 7 of set 5 | alushta
# Processing record 8 of set 5 | rumonge
# Processing record 9 of set 5 | oum hadjer
# Processing record 10 of set 5 | little current
# Processing record 11 of set 5 | salalah
# Processing record 12 of set 5 | nueva helvecia
# Processing record 13 of set 5 | pudozh
# Processing record 14 of set 5 | santa cruz del sur
# Processing record 15 of set 5 | hay river
# Processing record 16 of set 5 | saint-felicien
# Processing record 17 of set 5 | ahipara
# Processing record 18 of set 5 | camacha
# Processing record 19 of set 5 | ulagan
# Processing record 20 of set 5 | butaritari
# Processing record 21 of set 5 | saint-francois
# Processing record 22 of set 5 | bambous virieux
# Processing record 23 of set 5 | leningradskiy
# Processing record 24 of set 5 | laguna de perlas
# Processing record 25 of set 5 | adrar
# Processing record 26 of set 5 | ituni
# City not found. Skipping...
# Processing record 27 of set 5 | carnarvon
# Processing record 28 of set 5 | upernavik
# Processing record 29 of set 5 | airai
# Processing record 30 of set 5 | viedma
# Processing record 31 of set 5 | robertsport
# Processing record 32 of set 5 | lerwick
# Processing record 33 of set 5 | tromso
# Processing record 34 of set 5 | touba
# Processing record 35 of set 5 | pevek
# Processing record 36 of set 5 | palm valley
# Processing record 37 of set 5 | ipeti
# City not found. Skipping...
# Processing record 38 of set 5 | olafsvik
# Processing record 39 of set 5 | masjed-e soleyman
# City not found. Skipping...
# Processing record 40 of set 5 | cajibio
# Processing record 41 of set 5 | cockburn town
# Processing record 42 of set 5 | attawapiskat
# City not found. Skipping...
# Processing record 43 of set 5 | sirfa
# City not found. Skipping...
# Processing record 44 of set 5 | saleaula
# City not found. Skipping...
# Processing record 45 of set 5 | neiafu
# Processing record 46 of set 5 | tubuala
# Processing record 47 of set 5 | pullman
# Processing record 48 of set 5 | broken hill
# Processing record 49 of set 5 | tabiauea
# City not found. Skipping...
# Processing record 50 of set 5 | zarand
# Processing record 1 of set 6 | tiksi
# Processing record 2 of set 6 | requena
# Processing record 3 of set 6 | malwan
# City not found. Skipping...
# Processing record 4 of set 6 | thompson
# Processing record 5 of set 6 | vila velha
# Processing record 6 of set 6 | grindavik
# Processing record 7 of set 6 | luganville
# Processing record 8 of set 6 | tiznit
# Processing record 9 of set 6 | catio
# Processing record 10 of set 6 | gigmoto
# Processing record 11 of set 6 | faya
# Processing record 12 of set 6 | butterworth
# Processing record 13 of set 6 | la ronge
# Processing record 14 of set 6 | karatau
# Processing record 15 of set 6 | molokovo
# Processing record 16 of set 6 | syasstroy
# Processing record 17 of set 6 | majene
# Processing record 18 of set 6 | alta floresta
# Processing record 19 of set 6 | shache
# Processing record 20 of set 6 | hokitika
# Processing record 21 of set 6 | yulara
# Processing record 22 of set 6 | lanas
# Processing record 23 of set 6 | goma
# Processing record 24 of set 6 | san vicente
# Processing record 25 of set 6 | curup
# Processing record 26 of set 6 | coquimbo
# Processing record 27 of set 6 | am timan
# Processing record 28 of set 6 | kakori
# Processing record 29 of set 6 | silva jardim
# Processing record 30 of set 6 | praia da vitoria
# Processing record 31 of set 6 | marcona
# City not found. Skipping...
# Processing record 32 of set 6 | alenquer
# Processing record 33 of set 6 | asau
# Processing record 34 of set 6 | rio gallegos
# Processing record 35 of set 6 | tautira
# Processing record 36 of set 6 | tuatapere
# Processing record 37 of set 6 | arman
# Processing record 38 of set 6 | port blair
# Processing record 39 of set 6 | flinders
# Processing record 40 of set 6 | agirish
# Processing record 41 of set 6 | lalganj
# Processing record 42 of set 6 | bat khela
# Processing record 43 of set 6 | changli
# Processing record 44 of set 6 | olinda
# Processing record 45 of set 6 | port alfred
# Processing record 46 of set 6 | agadir
# Processing record 47 of set 6 | richards bay
# Processing record 48 of set 6 | muisne
# Processing record 49 of set 6 | mogadishu
# Processing record 50 of set 6 | nalut
# Processing record 1 of set 7 | velsk
# Processing record 2 of set 7 | grand gaube
# Processing record 3 of set 7 | nsoko
# Processing record 4 of set 7 | rehoboth
# Processing record 5 of set 7 | dauphin
# Processing record 6 of set 7 | xingyi
# Processing record 7 of set 7 | elliot lake
# Processing record 8 of set 7 | nome
# Processing record 9 of set 7 | miraflores
# Processing record 10 of set 7 | hovd
# Processing record 11 of set 7 | kavieng
# Processing record 12 of set 7 | berezovka
# Processing record 13 of set 7 | peace river
# Processing record 14 of set 7 | riyadh
# Processing record 15 of set 7 | alegrete
# Processing record 16 of set 7 | doha
# Processing record 17 of set 7 | maku
# Processing record 18 of set 7 | tidore
# City not found. Skipping...
# Processing record 19 of set 7 | avera
# Processing record 20 of set 7 | arani
# Processing record 21 of set 7 | tocopilla
# Processing record 22 of set 7 | tura
# Processing record 23 of set 7 | port hardy
# Processing record 24 of set 7 | el roble
# Processing record 25 of set 7 | moree
# Processing record 26 of set 7 | iwanai
# Processing record 27 of set 7 | fare
# Processing record 28 of set 7 | kuytun
# Processing record 29 of set 7 | baykit
# Processing record 30 of set 7 | hukuntsi
# Processing record 31 of set 7 | pangkalanbuun
# Processing record 32 of set 7 | show low
# Processing record 33 of set 7 | brae
# Processing record 34 of set 7 | miguel hidalgo
# Processing record 35 of set 7 | barentsburg
# City not found. Skipping...
# Processing record 36 of set 7 | wulanhaote
# City not found. Skipping...
# Processing record 37 of set 7 | wokha
# Processing record 38 of set 7 | teahupoo
# Processing record 39 of set 7 | ambilobe
# Processing record 40 of set 7 | yatou
# Processing record 41 of set 7 | vredendal
# Processing record 42 of set 7 | miramar
# Processing record 43 of set 7 | melfi
# Processing record 44 of set 7 | opuwo
# Processing record 45 of set 7 | ha tinh
# Processing record 46 of set 7 | ankazobe
# Processing record 47 of set 7 | andenes
# Processing record 48 of set 7 | bakal
# Processing record 49 of set 7 | mingyue
# Processing record 50 of set 7 | saravan
# Processing record 1 of set 8 | yangambi
# Processing record 2 of set 8 | saskylakh
# Processing record 3 of set 8 | dalbandin
# Processing record 4 of set 8 | turtas
# Processing record 5 of set 8 | kalinovskaya
# Processing record 6 of set 8 | lagoa
# Processing record 7 of set 8 | longyan
# Processing record 8 of set 8 | umm kaddadah
# Processing record 9 of set 8 | goundam
# Processing record 10 of set 8 | abu dhabi
# Processing record 11 of set 8 | quchan
# Processing record 12 of set 8 | palabuhanratu
# City not found. Skipping...
# Processing record 13 of set 8 | petropavlovka
# Processing record 14 of set 8 | severnyy
# Processing record 15 of set 8 | hualmay
# Processing record 16 of set 8 | reshetylivka
# Processing record 17 of set 8 | sosnovka
# Processing record 18 of set 8 | kabwe
# Processing record 19 of set 8 | filingue
# Processing record 20 of set 8 | samalaeulu
# City not found. Skipping...
# Processing record 21 of set 8 | mayo
# Processing record 22 of set 8 | mersing
# Processing record 23 of set 8 | maldonado
# Processing record 24 of set 8 | chabahar
# Processing record 25 of set 8 | korla
# Processing record 26 of set 8 | havelock
# Processing record 27 of set 8 | andevoranto
# City not found. Skipping...
# Processing record 28 of set 8 | sao joao da barra
# Processing record 29 of set 8 | det udom
# Processing record 30 of set 8 | dwarka
# Processing record 31 of set 8 | ribeira grande
# Processing record 32 of set 8 | benghazi
# Processing record 33 of set 8 | anta
# Processing record 34 of set 8 | bac lieu
# Processing record 35 of set 8 | sento se
# City not found. Skipping...
# Processing record 36 of set 8 | vestmannaeyjar
# Processing record 37 of set 8 | sedelnikovo
# City not found. Skipping...
# Processing record 38 of set 8 | kismayo
# Processing record 39 of set 8 | pangody
# Processing record 40 of set 8 | samarai
# Processing record 41 of set 8 | vila do maio
# Processing record 42 of set 8 | hamilton
# Processing record 43 of set 8 | margate
# Processing record 44 of set 8 | comodoro rivadavia
# Processing record 45 of set 8 | preeceville
# Processing record 46 of set 8 | grebenskaya
# Processing record 47 of set 8 | los llanos de aridane
# Processing record 48 of set 8 | la rioja
# Processing record 49 of set 8 | algiers
# Processing record 50 of set 8 | llallagua
# Processing record 1 of set 9 | toora-khem
# Processing record 2 of set 9 | roma
# Processing record 3 of set 9 | keningau
# Processing record 4 of set 9 | balikpapan
# Processing record 5 of set 9 | kampot
# Processing record 6 of set 9 | jinchengjiang
# City not found. Skipping...
# Processing record 7 of set 9 | san patricio
# Processing record 8 of set 9 | wajima
# Processing record 9 of set 9 | vaitupu
# City not found. Skipping...
# Processing record 10 of set 9 | mount isa
# Processing record 11 of set 9 | buin
# Processing record 12 of set 9 | lata
# Processing record 13 of set 9 | tambacounda
# Processing record 14 of set 9 | peniche
# Processing record 15 of set 9 | ifakara
# Processing record 16 of set 9 | pietarsaari
# Processing record 17 of set 9 | yar-sale
# Processing record 18 of set 9 | sisimiut
# Processing record 19 of set 9 | belaya gora
# Processing record 20 of set 9 | lundazi
# Processing record 21 of set 9 | le port
# Processing record 22 of set 9 | hambantota
# Processing record 23 of set 9 | khonuu
# City not found. Skipping...
# Processing record 24 of set 9 | geraldton
# Processing record 25 of set 9 | yanan
# City not found. Skipping...
# Processing record 26 of set 9 | mokhsogollokh
# Processing record 27 of set 9 | gunjur
# Processing record 28 of set 9 | guamuchil
# Processing record 29 of set 9 | marsa matruh
# Processing record 30 of set 9 | bonavista
# Processing record 31 of set 9 | great yarmouth
# Processing record 32 of set 9 | vanino
# Processing record 33 of set 9 | bojnurd
# Processing record 34 of set 9 | saint george
# Processing record 35 of set 9 | lolua
# City not found. Skipping...
# Processing record 36 of set 9 | severo-kurilsk
# Processing record 37 of set 9 | lujiang
# Processing record 38 of set 9 | navalmoral de la mata
# Processing record 39 of set 9 | aripuana
# Processing record 40 of set 9 | yumen
# Processing record 41 of set 9 | saldanha
# Processing record 42 of set 9 | lida
# Processing record 43 of set 9 | mocuba
# Processing record 44 of set 9 | touros
# Processing record 45 of set 9 | talavera
# Processing record 46 of set 9 | zarichne
# Processing record 47 of set 9 | imbituba
# Processing record 48 of set 9 | batemans bay
# Processing record 49 of set 9 | toliary
# City not found. Skipping...
# Processing record 50 of set 9 | gasa
# Processing record 1 of set 10 | elektrogorsk
# Processing record 2 of set 10 | sinnamary
# Processing record 3 of set 10 | grand river south east
# City not found. Skipping...
# Processing record 4 of set 10 | kaifeng
# Processing record 5 of set 10 | lamu
# Processing record 6 of set 10 | ponta delgada
# Processing record 7 of set 10 | scalloway
# City not found. Skipping...
# Processing record 8 of set 10 | semey
# Processing record 9 of set 10 | suntar
# Processing record 10 of set 10 | flagstaff
# Processing record 11 of set 10 | parry sound
# Processing record 12 of set 10 | dunedin
# Processing record 13 of set 10 | tiarei
# Processing record 14 of set 10 | rolim de moura
# City not found. Skipping...
# Processing record 15 of set 10 | yerbogachen
# Processing record 16 of set 10 | bridgton
# Processing record 17 of set 10 | temerloh
# Processing record 18 of set 10 | port macquarie
# Processing record 19 of set 10 | flin flon
# Processing record 20 of set 10 | nador
# Processing record 21 of set 10 | japura
# Processing record 22 of set 10 | russell
# Processing record 23 of set 10 | deshna
# City not found. Skipping...
# Processing record 24 of set 10 | totma
# Processing record 25 of set 10 | wageningen
# Processing record 26 of set 10 | qasigiannguit
# Processing record 27 of set 10 | diego de almagro
# Processing record 28 of set 10 | qiongshan
# Processing record 29 of set 10 | dombarovskiy
# Processing record 30 of set 10 | waipawa
# Processing record 31 of set 10 | ossora
# Processing record 32 of set 10 | kirensk
# Processing record 33 of set 10 | north battleford
# Processing record 34 of set 10 | manado
# Processing record 35 of set 10 | coihaique
# Processing record 36 of set 10 | stornoway
# Processing record 37 of set 10 | buritis
# Processing record 38 of set 10 | tilichiki
# Processing record 39 of set 10 | kyzyl-suu
# Processing record 40 of set 10 | port-cartier
# Processing record 41 of set 10 | hun
# Processing record 42 of set 10 | sentyabrskiy
# City not found. Skipping...
# Processing record 43 of set 10 | amapa
# Processing record 44 of set 10 | lasa
# Processing record 45 of set 10 | firozpur jhirka
# Processing record 46 of set 10 | kuche
# City not found. Skipping...
# Processing record 47 of set 10 | nichinan
# Processing record 48 of set 10 | senneterre
# Processing record 49 of set 10 | petropavlovsk-kamchatskiy
# Processing record 50 of set 10 | piterka
# Processing record 1 of set 11 | sorland
# Processing record 2 of set 11 | makung
# City not found. Skipping...
# Processing record 3 of set 11 | phuket
# Processing record 4 of set 11 | faanui
# Processing record 5 of set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing record 6 of set 11 | santa fe
# Processing record 7 of set 11 | mrirt
# City not found. Skipping...
# Processing record 8 of set 11 | emerald
# Processing record 9 of set 11 | miyazu
# Processing record 10 of set 11 | khandyga
# Processing record 11 of set 11 | sinjar
# Processing record 12 of set 11 | veraval
# Processing record 13 of set 11 | bat yam
# Processing record 14 of set 11 | panguipulli
# Processing record 15 of set 11 | san carlos de bariloche
# Processing record 16 of set 11 | magistralnyy
# Processing record 17 of set 11 | makhachkala
# Processing record 18 of set 11 | bilibino
# Processing record 19 of set 11 | saint-joseph
# Processing record 20 of set 11 | jacqueville
# Processing record 21 of set 11 | saint-georges
# Processing record 22 of set 11 | alberton
# Processing record 23 of set 11 | tazovskiy
# Processing record 24 of set 11 | storsteinnes
# Processing record 25 of set 11 | bronnoysund
# Processing record 26 of set 11 | tanout
# Processing record 27 of set 11 | bubaque
# Processing record 28 of set 11 | komsomolskiy
# Processing record 29 of set 11 | carballo
# Processing record 30 of set 11 | rungata
# City not found. Skipping...
# Processing record 31 of set 11 | gushi
# Processing record 32 of set 11 | yongan
# Processing record 33 of set 11 | rio brilhante
# Processing record 34 of set 11 | vanimo
# Processing record 35 of set 11 | grants
# Processing record 36 of set 11 | walvis bay
# Processing record 37 of set 11 | kayes
# Processing record 38 of set 11 | tolaga bay
# Processing record 39 of set 11 | eureka
# Processing record 40 of set 11 | klaksvik
# Processing record 41 of set 11 | morondava
# Processing record 42 of set 11 | yelandur
# Processing record 43 of set 11 | kodinsk
# Processing record 44 of set 11 | kalmunai
# Processing record 45 of set 11 | cabedelo
# Processing record 46 of set 11 | auki
# Processing record 47 of set 11 | pio ix
# Processing record 48 of set 11 | suez
# Processing record 49 of set 11 | zhezkazgan
# Processing record 50 of set 11 | college
# Processing record 1 of set 12 | warqla
# City not found. Skipping...
# Processing record 2 of set 12 | naliya
# Processing record 3 of set 12 | norrtalje
# Processing record 4 of set 12 | kallithea
# Processing record 5 of set 12 | sturgis
# Processing record 6 of set 12 | sotouboua
# Processing record 7 of set 12 | bambanglipuro
# Processing record 8 of set 12 | anloga
# Processing record 9 of set 12 | kamogawa
# Processing record 10 of set 12 | illora
# Processing record 11 of set 12 | acapulco
# Processing record 12 of set 12 | ngukurr
# City not found. Skipping...
# Processing record 13 of set 12 | warrensburg
# Processing record 14 of set 12 | mullaitivu
# City not found. Skipping...
# Processing record 15 of set 12 | nouadhibou
# Processing record 16 of set 12 | danilovka
# Processing record 17 of set 12 | the pas
# Processing record 18 of set 12 | guangyuan
# Processing record 19 of set 12 | nehe
# Processing record 20 of set 12 | khasan
# Processing record 21 of set 12 | kharp
# Processing record 22 of set 12 | pak chong
# Processing record 23 of set 12 | manaure
# Processing record 24 of set 12 | sinkat
# City not found. Skipping...
# Processing record 25 of set 12 | berdyuzhye
# City not found. Skipping...
# Processing record 26 of set 12 | kyshtovka
# Processing record 27 of set 12 | grand-santi
# Processing record 28 of set 12 | itaituba
# Processing record 29 of set 12 | meulaboh
# Processing record 30 of set 12 | shingu
# Processing record 31 of set 12 | bacuit
# City not found. Skipping...
# Processing record 32 of set 12 | americus
# Processing record 33 of set 12 | ginir
# Processing record 34 of set 12 | cayenne
# Processing record 35 of set 12 | apodi
# Processing record 36 of set 12 | dawson creek
# Processing record 37 of set 12 | benemerito de las americas
# Processing record 38 of set 12 | sao sebastiao
# Processing record 39 of set 12 | fukue
# Processing record 40 of set 12 | broome
# Processing record 41 of set 12 | labuhan
# Processing record 42 of set 12 | namibe
# Processing record 43 of set 12 | verkh-usugli
# Processing record 44 of set 12 | floresta
# Processing record 45 of set 12 | novo cruzeiro
# Processing record 46 of set 12 | cotonou
# Processing record 47 of set 12 | harper
# Processing record 48 of set 12 | aksay
# Processing record 49 of set 12 | madimba
# Processing record 50 of set 12 | olden
# Processing record 1 of set 13 | dzhebariki-khaya
# Processing record 2 of set 13 | maraa
# Processing record 3 of set 13 | saint-augustin
# Processing record 4 of set 13 | utete
# Processing record 5 of set 13 | tinskoy
# Processing record 6 of set 13 | rocha
# Processing record 7 of set 13 | kargasok
# Processing record 8 of set 13 | pedra
# Processing record 9 of set 13 | san cristobal
# Processing record 10 of set 13 | poronaysk
# Processing record 11 of set 13 | lulea
# Processing record 12 of set 13 | lensk
# Processing record 13 of set 13 | phan thiet
# Processing record 14 of set 13 | suba
# Processing record 15 of set 13 | campos novos
# Processing record 16 of set 13 | arona
# Processing record 17 of set 13 | abeche
# Processing record 18 of set 13 | aklavik
# Processing record 19 of set 13 | hvammstangi
# City not found. Skipping...
# Processing record 20 of set 13 | svetlyy
# Processing record 21 of set 13 | varkkallai
# Processing record 22 of set 13 | sucua
# Processing record 23 of set 13 | hinton
# Processing record 24 of set 13 | nishihara
# Processing record 25 of set 13 | beringovskiy
# Processing record 26 of set 13 | san pedro
# Processing record 27 of set 13 | ahome
# Processing record 28 of set 13 | mirabad
# Processing record 29 of set 13 | itarema
# Processing record 30 of set 13 | guatire
# Processing record 31 of set 13 | tuzha
# Processing record 32 of set 13 | sao filipe
# Processing record 33 of set 13 | rantepao
# Processing record 34 of set 13 | saint anthony
# Processing record 35 of set 13 | mehran
# Processing record 36 of set 13 | radcliff
# Processing record 37 of set 13 | taoudenni
# Processing record 38 of set 13 | sampit
# Processing record 39 of set 13 | inuvik
# Processing record 40 of set 13 | bath
# Processing record 41 of set 13 | shizunai
# Processing record 42 of set 13 | deputatskiy
# Processing record 43 of set 13 | saint-gilles
# Processing record 44 of set 13 | numan
# Processing record 45 of set 13 | rafaela
# Processing record 46 of set 13 | krasnyy yar
# Processing record 47 of set 13 | quatre cocos
# Processing record 48 of set 13 | jega
# Processing record 49 of set 13 | yomitan
# City not found. Skipping...
# Processing record 50 of set 13 | kibungo
# Processing record 1 of set 14 | bjerkvik
# Processing record 2 of set 14 | mergui
# City not found. Skipping...
# Processing record 3 of set 14 | satitoa
# City not found. Skipping...
# Processing record 4 of set 14 | panguna
# Processing record 5 of set 14 | padang
# Processing record 6 of set 14 | anadyr
# Processing record 7 of set 14 | balakhta
# Processing record 8 of set 14 | asyut
# Processing record 9 of set 14 | murray bridge
# Processing record 10 of set 14 | stromness
# Processing record 11 of set 14 | elko
# Processing record 12 of set 14 | mazamet
# Processing record 13 of set 14 | toktogul
# Processing record 14 of set 14 | coolum beach
# Processing record 15 of set 14 | sassandra
# Processing record 16 of set 14 | chilca
# Processing record 17 of set 14 | gurgan
# City not found. Skipping...
# Processing record 18 of set 14 | dingle
# Processing record 19 of set 14 | nemuro
# Processing record 20 of set 14 | pyapon
# Processing record 21 of set 14 | oranjemund
# Processing record 22 of set 14 | valenca
# Processing record 23 of set 14 | port hedland
# Processing record 24 of set 14 | bihac
# Processing record 25 of set 14 | puerto madryn
# Processing record 26 of set 14 | lusaka
# Processing record 27 of set 14 | aykhal
# Processing record 28 of set 14 | almaznyy
# Processing record 29 of set 14 | valparaiso
# Processing record 30 of set 14 | oltu
# Processing record 31 of set 14 | verkhnevilyuysk
# Processing record 32 of set 14 | borgarnes
# Processing record 33 of set 14 | plouzane
# Processing record 34 of set 14 | puerto lopez
# Processing record 35 of set 14 | cozumel
# Processing record 36 of set 14 | kisangani
# Processing record 37 of set 14 | praya
# Processing record 38 of set 14 | mombasa
# Processing record 39 of set 14 | shieli
# Processing record 40 of set 14 | sarh
# Processing record 41 of set 14 | semnan
# Processing record 42 of set 14 | redcliffe
# Processing record 43 of set 14 | san ramon
# Processing record 44 of set 14 | cabatuan
# Processing record 45 of set 14 | kigoma
# Processing record 46 of set 14 | linjiang
# Processing record 47 of set 14 | betsiamites
# Processing record 48 of set 14 | leshukonskoye
# Processing record 49 of set 14 | praia
# Processing record 50 of set 14 | samarinda
# Processing record 1 of set 15 | bainbridge
# Processing record 2 of set 15 | kudahuvadhoo
# Processing record 3 of set 15 | iracoubo
# Processing record 4 of set 15 | tecoanapa
# Processing record 5 of set 15 | zharkent
# Processing record 6 of set 15 | rohtak
# Processing record 7 of set 15 | vao
# Processing record 8 of set 15 | kediri
# Processing record 9 of set 15 | nuuk
# Processing record 10 of set 15 | cheyenne
# Processing record 11 of set 15 | jutai
# Processing record 12 of set 15 | novobirilyussy
# Processing record 13 of set 15 | viligili
# City not found. Skipping...
# Processing record 14 of set 15 | kasempa
# Processing record 15 of set 15 | palana
# Processing record 16 of set 15 | angoche
# Processing record 17 of set 15 | bouake
# Processing record 18 of set 15 | shubarshi
# Processing record 19 of set 15 | najran
# Processing record 20 of set 15 | dryden
# Processing record 21 of set 15 | managua
# Processing record 22 of set 15 | zabaykalsk
# Processing record 23 of set 15 | shirokiy
# Processing record 24 of set 15 | jiroft
# City not found. Skipping...
# Processing record 25 of set 15 | joshimath
# Processing record 26 of set 15 | pidhorodne
# Processing record 27 of set 15 | leh
# Processing record 28 of set 15 | plettenberg bay
# Processing record 29 of set 15 | hihifo
# City not found. Skipping...
# Processing record 30 of set 15 | ulaanbaatar
# Processing record 31 of set 15 | bur gabo
# City not found. Skipping...
# Processing record 32 of set 15 | azimur
# City not found. Skipping...
# Processing record 33 of set 15 | mwinilunga
# Processing record 34 of set 15 | saint-leu
# Processing record 35 of set 15 | beloha
# Processing record 36 of set 15 | cascais
# Processing record 37 of set 15 | mackay
# Processing record 38 of set 15 | carutapera
# Processing record 39 of set 15 | bereda
# Processing record 40 of set 15 | halifax
# Processing record 41 of set 15 | raudeberg
# Processing record 42 of set 15 | pontianak
# Processing record 43 of set 15 | longyearbyen
# Processing record 44 of set 15 | ginda
# Processing record 45 of set 15 | umea
# ---------------------------
# done

# %%
len(city_data)
# Out:
# 681

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Albany  42.6001  -73.9662     71.62        93         100
# 1   Cabo San Lucas  22.8909 -109.9124     91.51        72          20
# 2  Haines Junction  60.7522 -137.5108     69.75        46          38
# 3        Esperance -33.8667  121.9000     55.24        67          97
# 4            Vaini -21.2000 -175.2000     75.36        88          75
# 5          Honiara  -9.4333  159.9500     87.19        65          13
# 6           Vostok  46.4856  135.8833     71.06        90         100
# 7     Punta Arenas -53.1500  -70.9167     39.11        87           0
# 8         Victoria  22.2855  114.1577     82.38        93         100
# 9        Nchelenge  -9.3451   28.7340     59.16        52           0
#
#    Wind Speed Country      Current Description
# 0        5.23      US          overcast clouds
# 1        5.99      MX               few clouds
# 2        8.05      CA         scattered clouds
# 3       26.69      AU          overcast clouds
# 4        6.91      TO  light intensity drizzle
# 5        7.14      SB               few clouds
# 6        1.59      RU          overcast clouds
# 7       17.27      CL                clear sky
# 8        1.01      HK               light rain
# 9        7.38      ZM                clear sky

# %%
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df =city_data_df[column_order]
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Albany      US  42.6001  -73.9662     71.62        93         100
# 1   Cabo San Lucas      MX  22.8909 -109.9124     91.51        72          20
# 2  Haines Junction      CA  60.7522 -137.5108     69.75        46          38
# 3        Esperance      AU -33.8667  121.9000     55.24        67          97
# 4            Vaini      TO -21.2000 -175.2000     75.36        88          75
#
#    Wind Speed      Current Description
# 0        5.23          overcast clouds
# 1        5.99               few clouds
# 2        8.05         scattered clouds
# 3       26.69          overcast clouds
# 4        6.91  light intensity drizzle

# %%
# Create output file
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
